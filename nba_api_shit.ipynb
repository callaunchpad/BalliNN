# %%
import pandas as pd
import numpy as np

# %%
team_arr = []
tids = np.arange(30)
tids = tids + 1610612737
for tid in tids:
    team = teamyearbyyearstats.TeamYearByYearStats(team_id = tid)
    team_arr.append(team.get_data_frames())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-66de2c91255e> in <module>
#       3 tids = tids + 1610612737
#       4 for tid in tids:
# ----> 5     team = teamyearbyyearstats.TeamYearByYearStats(team_id = tid)
#       6     team_arr.append(team.get_data_frames())
#
# NameError: name 'teamyearbyyearstats' is not defined

# %%
team_concat = pd.concat(team_arr, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-4efe19cb8700> in <module>
# ----> 1 team_concat = pd.concat(team_arr, axis = 1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
# ...

# %% [markdown]
# Below code creates a list of dataframes where each individual one is a single team.

# %%
from nba_api.stats.endpoints import teamyearbyyearstats
team_id = 1610612737
team_arr = []
for i in range(30):
    team = teamyearbyyearstats.TeamYearByYearStats(team_id+i, timeout=500)
    team_arr.append([team.get_data_frames()[0]])
team_arr[0]
# Out:
# [       TEAM_ID   TEAM_CITY   TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
#  0   1610612737  Tri-Cities  Blackhawks  1949-50  64    29      35    0.453
#  1   1610612737  Tri-Cities  Blackhawks  1950-51  68    25      43    0.368
#  2   1610612737   Milwaukee       Hawks  1951-52  66    17      49    0.258
#  3   1610612737   Milwaukee       Hawks  1952-53  71    27      44    0.380
#  4   1610612737   Milwaukee       Hawks  1953-54  72    21      51    0.292
#  5   1610612737   Milwaukee       Hawks  1954-55  72    26      46    0.361
#  6   1610612737   St. Louis       Hawks  1955-56  72    33      39    0.458
#  7   1610612737   St. Louis       Hawks  1956-57  72    34      38    0.472
#  8   1610612737   St. Louis       Hawks  1957-58  72    41      31    0.569
#  9   1610612737   St. Louis       Hawks  1958-59  72    49      23    0.681
#  10  1610612737   St. Louis       Hawks  1959-60  75    46      29    0.613
# ...

# %% [markdown]
# arr is a single dataframe which has each team's data appended to it, so it contains all the team data from every season

# %%
arr = pd.DataFrame()
for i in range(30):
    arr = arr.append(team_arr[i][0])
arr
# Out:
#        TEAM_ID   TEAM_CITY   TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612737  Tri-Cities  Blackhawks  1949-50  64    29      35    0.453
# 1   1610612737  Tri-Cities  Blackhawks  1950-51  68    25      43    0.368
# 2   1610612737   Milwaukee       Hawks  1951-52  66    17      49    0.258
# 3   1610612737   Milwaukee       Hawks  1952-53  71    27      44    0.380
# 4   1610612737   Milwaukee       Hawks  1953-54  72    21      51    0.292
# 5   1610612737   Milwaukee       Hawks  1954-55  72    26      46    0.361
# 6   1610612737   St. Louis       Hawks  1955-56  72    33      39    0.458
# 7   1610612737   St. Louis       Hawks  1956-57  72    34      38    0.472
# 8   1610612737   St. Louis       Hawks  1957-58  72    41      31    0.569
# 9   1610612737   St. Louis       Hawks  1958-59  72    49      23    0.681
# 10  1610612737   St. Louis       Hawks  1959-60  75    46      29    0.613
# ...

# %% [markdown]
# This groups all the data in total data array and gets a group from a single year

# %%
arr.groupby(['YEAR']).get_group('1980-81')
# Out:
#        TEAM_ID     TEAM_CITY      TEAM_NAME     YEAR  GP  WINS  LOSSES  \
# 31  1610612737       Atlanta          Hawks  1980-81  82    31      51
# 34  1610612738        Boston        Celtics  1980-81  82    62      20
# 10  1610612739     Cleveland      Cavaliers  1980-81  82    28      54
# 14  1610612741       Chicago          Bulls  1980-81  82    45      37
# 0   1610612742        Dallas      Mavericks  1980-81  82    15      67
# 4   1610612743        Denver        Nuggets  1980-81  82    37      45
# 34  1610612744  Golden State       Warriors  1980-81  82    39      43
# 13  1610612745       Houston        Rockets  1980-81  82    40      42
# 10  1610612746     San Diego       Clippers  1980-81  82    36      46
# 32  1610612747   Los Angeles         Lakers  1980-81  82    54      28
# 12  1610612749     Milwaukee          Bucks  1980-81  82    60      22
# 4   1610612751    New Jersey           Nets  1980-81  82    24      58
# ...

# %% [markdown]
# Resets the index labels to 0 for a given season

# %% [markdown]
# First need number of 0's for set axis array, which is num rows

# %%
size_1980 = np.size(arr_1980.values,0)

# %%
arr_1980 = arr.groupby(['YEAR']).get_group('1980-81').set_axis(([0]*size_1980), axis='index', inplace=False)

# %%
arr_1980
# Out:
#       TEAM_ID     TEAM_CITY      TEAM_NAME     YEAR  GP  WINS  LOSSES  \
# 0  1610612737       Atlanta          Hawks  1980-81  82    31      51
# 0  1610612738        Boston        Celtics  1980-81  82    62      20
# 0  1610612739     Cleveland      Cavaliers  1980-81  82    28      54
# 0  1610612741       Chicago          Bulls  1980-81  82    45      37
# 0  1610612742        Dallas      Mavericks  1980-81  82    15      67
# 0  1610612743        Denver        Nuggets  1980-81  82    37      45
# 0  1610612744  Golden State       Warriors  1980-81  82    39      43
# 0  1610612745       Houston        Rockets  1980-81  82    40      42
# 0  1610612746     San Diego       Clippers  1980-81  82    36      46
# 0  1610612747   Los Angeles         Lakers  1980-81  82    54      28
# 0  1610612749     Milwaukee          Bucks  1980-81  82    60      22
# 0  1610612751    New Jersey           Nets  1980-81  82    24      58
# ...

# %% [markdown]
# Access a specific column for every team

# %%
arr_1980.at[0,'WINS']
# Out:
# array([31, 62, 28, 45, 15, 37, 39, 40, 36, 54, 60, 24, 50, 44, 62, 57, 45,
#        40, 52, 34, 28, 39, 21])

# %% [markdown]
# This is the first year each team was active

# %%
arr.at[0, 'YEAR']
# Out:
# array(['1949-50', '1946-47', '1970-71', '2002-03', '1966-67', '1980-81',
#        '1976-77', '1946-47', '1967-68', '1970-71', '1948-49', '1988-89',
#        '1968-69', '1989-90', '1976-77', '1946-47', '1989-90', '1976-77',
#        '1949-50', '1968-69', '1970-71', '1948-49', '1976-77', '1967-68',
#        '1995-96', '1974-75', '1995-96', '1961-62', '1948-49', '1988-89'],
#       dtype=object)

# %% [markdown]
# This line gets the third team in team_arr, acceses its dataframe, and does.loc, which gets the 7th row

# %%
team_arr[2][0].loc[[7]] #Cavs in 1997
# Out:
#       TEAM_ID  TEAM_CITY  TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 7  1610612739  Cleveland  Cavaliers  1977-78  82    43      39    0.524
#
#    CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# 7          4         3  ...  1187  2676  3863  1740  1832  692  1382  455
#
#     PTS  PTS_RANK
# 7  8561        19
#
# [1 rows x 34 columns]

# %% [markdown]
# Test on appending dataframes and then accessing a certain row. Issue is the years are not the same as the teams started in different years

# %%
team_arr[0][0].append(team_arr[1][0], ignore_index=False).loc[[29]]
# Out:
#        TEAM_ID TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 29  1610612737   Atlanta     Hawks  1978-79  82    46      36    0.561
# 29  1610612738    Boston   Celtics  1975-76  82    54      28    0.659
#
#     CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# 29          5         3  ...  1381  2341  3722  1938  2424  801  1523  596
# 29          1         1  ...  1369  2972  4341  1980  2002  561  1609  260
#
#      PTS  PTS_RANK
# 29  8950        12
# 29  8708         6
#
# [2 rows x 34 columns]

# %% [markdown]
# Accessing the first team's Pt rank in the second year they were active

# %%
team_arr[0][0].at[1, 'PTS_RANK']
# Out:
# 3

# %%
team_arr[1][0]
# Out:
#        TEAM_ID TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612738    Boston   Celtics  1946-47  60    22      38    0.367
# 1   1610612738    Boston   Celtics  1947-48  48    20      28    0.417
# 2   1610612738    Boston   Celtics  1948-49  60    25      35    0.417
# 3   1610612738    Boston   Celtics  1949-50  68    22      46    0.324
# 4   1610612738    Boston   Celtics  1950-51  69    39      30    0.565
# 5   1610612738    Boston   Celtics  1951-52  66    39      27    0.591
# 6   1610612738    Boston   Celtics  1952-53  71    46      25    0.648
# 7   1610612738    Boston   Celtics  1953-54  72    42      30    0.583
# 8   1610612738    Boston   Celtics  1954-55  72    36      36    0.500
# 9   1610612738    Boston   Celtics  1955-56  72    39      33    0.542
# 10  1610612738    Boston   Celtics  1956-57  72    44      28    0.611
# 11  1610612738    Boston   Celtics  1957-58  72    49      23    0.681
# ...

# %%
from nba_api.stats.endpoints import commonplayerinfo

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)
player_info.player_headline_stats.get_data_frame()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
# ...

# %% [markdown]
# Only shows basic stats (not very helpful).

# %%
from nba_api.stats.endpoints import playercareerstats

# %%
career = playercareerstats.PlayerCareerStats(player_id='2544')
career.get_data_frames()[0]
# career.season_totals_regular_season.get_dict()
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
career.get_dict()
# nba_players = players.get_players()
# for player in nba_players:
#     career = playercareerstats.PlayerCareerStats(player_id=player["id"])
# Out:
# {'resource': 'playercareerstats',
#  'parameters': {'PerMode': 'Totals', 'PlayerID': 2544, 'LeagueID': None},
#  'resultSets': [{'name': 'SeasonTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[2544,
#      '2003-04',
#      '00',
#      1610612739,
#      'CLE',
#      19.0,
#      79,
#      79,
#      3120.0,
#      622,
#      1492,
#      0.417,
#      63,
#      217,
#      0.29,
#      347,
#      460,
#      0.754,
#      99,
#      333,
#      432,
#      465,
#      130,
#      58,
#      273,
#      149,
#      1654],
#     [2544,
#      '2004-05',
#      '00',
# ...

# %%
from nba_api.stats.endpoints import commonteamroster

# %%
cr = commonteamroster.CommonTeamRoster("1610612739", "2018-19")
cr.get_data_frames()[0]
# Out:
#         TeamID SEASON LeagueID               PLAYER NUM POSITION HEIGHT  \
# 0   1610612739   2018       00           Kevin Love   0      F-C   6-10
# 1   1610612739   2018       00         Nik Stauskas   1        G    6-6
# 2   1610612739   2018       00        Collin Sexton   2        G    6-2
# 3   1610612739   2018       00      Marquese Chriss   3        F   6-10
# 4   1610612739   2018       00    Jaron Blossomgame   4        F    6-8
# 5   1610612739   2018       00             JR Smith   5      G-F    6-6
# 6   1610612739   2018       00      Jordan Clarkson   8        G    6-5
# 7   1610612739   2018       00        Channing Frye   9      F-C    7-0
# 8   1610612739   2018       00          David Nwaba  12        G    6-4
# 9   1610612739   2018       00     Tristan Thompson  13      C-F   6-10
# 10  1610612739   2018       00           Cedi Osman  16        F    6-8
# 11  1610612739   2018       00  Matthew Dellavedova  18        G    6-4
# ...

# %%
from nba_api.stats.endpoints import teamyearbyyearstats

# %%
teamyearbyyearstats.TeamYearByYearStats(1610612739).get_data_frames()[0]
# Out:
#        TEAM_ID  TEAM_CITY  TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612739  Cleveland  Cavaliers  1970-71  82    15      67    0.183
# 1   1610612739  Cleveland  Cavaliers  1971-72  82    23      59    0.280
# 2   1610612739  Cleveland  Cavaliers  1972-73  82    32      50    0.390
# 3   1610612739  Cleveland  Cavaliers  1973-74  82    29      53    0.354
# 4   1610612739  Cleveland  Cavaliers  1974-75  82    40      42    0.488
# 5   1610612739  Cleveland  Cavaliers  1975-76  82    49      33    0.598
# 6   1610612739  Cleveland  Cavaliers  1976-77  82    43      39    0.524
# 7   1610612739  Cleveland  Cavaliers  1977-78  82    43      39    0.524
# 8   1610612739  Cleveland  Cavaliers  1978-79  82    30      52    0.366
# 9   1610612739  Cleveland  Cavaliers  1979-80  82    37      45    0.451
# 10  1610612739  Cleveland  Cavaliers  1980-81  82    28      54    0.341
# 11  1610612739  Cleveland  Cavaliers  1981-82  82    15      67    0.183
# ...
